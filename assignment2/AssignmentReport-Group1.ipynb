# %% [markdown]
# # Assignment 1 Report

# %% [markdown]
# # Task 1

# %% [markdown]
# ## task 1a)
#
# ![151625822_254198696215417_4600537175174309018_n.jpg](attachment:151625822_254198696215417_4600537175174309018_n.jpg)

# %% [markdown]
# ## task 1b)
#
# ![151660333_232164085245201_2514377743093119877_n.jpg](attachment:151660333_232164085245201_2514377743093119877_n.jpg)

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Task 2c)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Task 2d)

# %% [markdown]
# $$ Number of parameters = number of weights + number of biases = number of inputs(+bias) * nodes in first layer + nodes in first layer * nodes in output layer $$
# $$ Number of paramteres = 785 * 65 + 64 * 10 = 50880 $$

# %% [markdown]
# # Task 3

# %% [markdown]
# ## Improved weight initalization
# convergence speed: The convergeance speed is about the same as before.
#
# generalization/overfitting:The model starts to overfits from about step 2-3000.
#
# final accuracy: The final accuracy has imrpoved a lot. About 4 %.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Adding sigmoid function
# convergence speed:The convergeance is faster now.
#
# generalization/overfitting:The model overfits even more and quicker.
#
# final accuracy: The final accuracy might have improved a littel bit, but not much
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Adding momentum
# Here i changed the learning_rate to 0.02
# convergence speed:The convergeance speed is about the same as before
#
# generalization/overfitting: The overfitting is about the same ass before.
#
# final accuracy: The final accuracy has imrpoved a littel bit.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Task 4

# %% [markdown]
# ## Task 4a)
# The final accuracy becomes lower. About two perecent. The accuracy does also fluxuate a lot more. Its more "noisy".
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Task 4b)
# This model is really similar too the one with 64 hidden units.
# If we combare it too the one with 32 hidden units, we can see that its more overfitted and the overfitting happens very rapid.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Task 4d)
# $$ Number of parameters = 50880 $$
# To find Number of nodes per hidden layer we get the following equation
# $$ 50880 = 785*x + x*x + x*10 $$
# solving this eqution for x gives x = 59,541
# We will therfore sett the size of the two hidden layers equal to 60 nodes.
# This gives the new network
# $$ Number of paramters = 785*60 + 60*60 + 60*10 = 51300$$
# ![image.png](attachment:image.png)
#
# The model behaves quit similarly to thh one from task 3. Its hard to notice anything that is worth mentioning. There is no advantages to choosing this model ass it will take longer time to compute each step.

# %% [markdown]
# ## Task 4e)
# I kept number_of_epochs = 50 and ploted it together with the model from task 4d.
# Here we see that the new model is definitaly overfiiting. The validattion accuracy is actually getting lower after about 10000 steps. This is due too the high complexity in our model. The high complexity allowes the model to overfit soo much that it causes the validation accuracy to decrease.
# ![image.png](attachment:image.png)
